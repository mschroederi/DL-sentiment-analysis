# %%
import matplotlib.pyplot as plt

accuracies = [(0, 0.5), (1, 0.57188), (2, 0.57188), (4, 0.63436), (8, 0.66444), (16, 0.7014), (32, 0.73428), (64, 0.77588), (128, 0.80088), (256, 0.81924), (512, 0.8272), (1024, 0.84576), (2048, 0.85724), (4096, 0.86556), (8192, 0.87132), (16384, 0.8744), (32768, 0.88084), (65536, 0.88288), (76285, 0.88272)]
accuracies2 = [(0, 0.5), (2, 0.57188), (4, 0.604), (8, 0.63996), (16, 0.67964), (32, 0.72272), (64, 0.77964), (128, 0.79952), (256, 0.81764), (512, 0.83072), (1024, 0.84584), (2048, 0.85704), (4096, 0.86496), (8192, 0.8704), (16384, 0.87172), (32768, 0.88024), (65536, 0.88236), (76285, 0.88272)]

X1 = [x[0] for x in accuracies]
# X1 = [str(x[0]) for x in accuracies]
Y1 = [x[1] for x in accuracies]

X2 = [x[0] for x in accuracies2]
# X2 = [str(x[0]) for x in accuracies2]
Y2 = [x[1] for x in accuracies2]

plt.figure(figsize=(16, 8))

plt.plot(X1, Y1, label="Heighest Contribution")
# plt.plot(X2, Y2, label="Same number Pos and Neg")

plt.xscale("symlog", basex=10)
plt.legend()
plt.show()
